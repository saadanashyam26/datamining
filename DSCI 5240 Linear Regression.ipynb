# %% [markdown]
# ### Week 3 Linear Regression

# %%
# This code appears in every demonstration Notebook.
# By default, when you run each cell, only the last output of the codes will show.
# This code makes all outputs of a cell show.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# We will explore the user and order data from JD.com.

# %% [markdown]
# 1. We import the necessary packages.

# %%
import pandas as pd
import statsmodels.api as sm
# api submodule gives access to the most commonly used 
# classes and functions directly.

# %% [markdown]
# 2. We read in the datasets.

# %%
ads = pd.read_csv('Advertising (1).csv')
# if we use absolute oath
#ads =pd.read_csv("\\filepath ")

# %%
ads.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# Delete a column
ads.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
del ads['Unnamed: 0']

# %%
ads.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# 3. Run the linear regression model

# %%
# prepare the variables:dependent,independent and the constant
y = ads['sales']

X = ads[['TV', 'radio', 'newspaper']]

X_with_intercept = sm.add_constant(X)

# Fit the linear regression model ols means ordinatry list square
model = sm.OLS(y, X_with_intercept)
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           1.58e-96
# Time:                        14:47:02   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
#make predictions #use predict() to make predictions
sales_predicted = results.predict(X_with_intercept)

# %%
ads['sales_predicted']= sales_predicted
ads.head()
# Out:
#       TV  radio  newspaper  sales  sales_predicted
# 0  230.1   37.8       69.2   22.1        20.523974
# 1   44.5   39.3       45.1   10.4        12.337855
# 2   17.2   45.9       69.3    9.3        12.307671
# 3  151.5   41.3       58.5   18.5        17.597830
# 4  180.8   10.8       58.4   12.9        13.188672

# %%
import sklearn
import math

from sklearn.metrics import mean_squared_error
mean_squared_error
# Out:
# <function sklearn.metrics._regression.mean_squared_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average', squared=True)>

# %%
#to get the number of 
ads.shape[0]
# Out:
# 200

# %%
mean_squared_error(ads['sales'],ads['sales_predicted'], squared = False)
# Out:
# 1.6685701407225697

# %%
mse = sum((ads['sales_predicted'] - ads['sales'])**2) / ads.shape[0]

# %%
mse
# Out:
# 2.784126314510937

# %%
import math
rmse=math.sqrt(mse)
rmse
# Out:
# 1.66857014072257

# %%
#to implement interation terms
ads['TVXRadio'] =ads['TV'] * ads['radio']

# %%
ads.head()
# Out:
#       TV  radio  newspaper  sales  sales_predicted  TVXRadio
# 0  230.1   37.8       69.2   22.1        20.523974   8697.78
# 1   44.5   39.3       45.1   10.4        12.337855   1748.85
# 2   17.2   45.9       69.3    9.3        12.307671    789.48
# 3  151.5   41.3       58.5   18.5        17.597830   6256.95
# 4  180.8   10.8       58.4   12.9        13.188672   1952.64

# %%
# prepare the variables:dependent,independent and the constant
y = ads['sales']

X_interact = ads[['TV', 'radio', 'TVXRadio']]

X_with_interact = sm.add_constant(X_interact)

# Fit the linear regression model ols means ordinatry list square
model_interact = sm.OLS(y, X_with_interact)
results_interact = model_interact.fit()

# %%
results_interact.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     1963.
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):          6.68e-146
# Time:                        15:46:03   Log-Likelihood:                -270.14
# No. Observations:                 200   AIC:                             548.3
# Df Residuals:                     196   BIC:                             561.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.7502      0.248     27.233      0.000       6.261       7.239
# ...

# %%
happy = pd.read_csv('Happiness2019.csv')

# %%
happy.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
happy.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
#how social and economic factors affect the happiness? 
#prediction vs inference
#predictive question
#descriptive question like which country is doing very good in economy by seeing the gdp per capita,
#which countries are happy?
#we can define that if their happiness score above average ,they are happy

# %%
happy['Score'].mean()
# Out:
# 5.407096153846155

# %%
happy_countries = happy[happy['Score']>happy['Score'].mean()]
happy_countries.head(50)
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 0              1               Finland  7.769           1.340           1.587
# 1              2               Denmark  7.600           1.383           1.573
# 2              3                Norway  7.554           1.488           1.582
# 3              4               Iceland  7.494           1.380           1.624
# 4              5           Netherlands  7.488           1.396           1.522
# 5              6           Switzerland  7.480           1.452           1.526
# 6              7                Sweden  7.343           1.387           1.487
# 7              8           New Zealand  7.307           1.303           1.557
# 8              9                Canada  7.278           1.365           1.505
# 9             10               Austria  7.246           1.376           1.475
# 10            11             Australia  7.228           1.372           1.548
# ...

# %%
#which country is least happy?

# %%
happy[happy['Score']==happy['Score'].min()]
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 155           156       South Sudan  2.853           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 155                    0.295                          0.01       0.202
#
#      Perceptions of corruption
# 155                      0.091

# %%
happy.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
#using linear regression for answering predictive
# prepare the variables:dependent,independent and the constant
y = happy['Score']

X = happy[['GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']]

X_with_intercept = sm.add_constant(X)

# Fit the linear regression model ols means ordinatry list square
model = sm.OLS(y, X_with_intercept)
resulte = model.fit()

# %%
resulte.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Score   R-squared:                       0.779
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                     87.62
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           2.40e-46
# Time:                        14:47:02   Log-Likelihood:                -119.76
# No. Observations:                 156   AIC:                             253.5
# Df Residuals:                     149   BIC:                             274.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
#dummy variable

# %%
toyata = pd.read_csv('ToyotaCorolla.csv')

# %%
toyata.head()
# Out:
#    Price  Age     KM Fuel_Type  HP  MetColor  Automatic  Doors
# 0  13500   23  46986    Diesel  90         1          0      3
# 1  13750   23  72937    Diesel  90         1          0      3
# 2  13950   24  41711    Diesel  90         1          0      3
# 3  14950   26  48000    Diesel  90         0          0      3
# 4  13750   30  38500    Diesel  90         0          0      3

# %%
toyata.columns
# Out:
# Index(['Price', 'Age', 'KM', 'Fuel_Type', 'HP', 'MetColor', 'Automatic',
#        'Doors'],
#       dtype='object')

# %%
toyata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   MetColor   1436 non-null   int64
#  6   Automatic  1436 non-null   int64
#  7   Doors      1436 non-null   int64
# dtypes: int64(7), object(1)
# memory usage: 89.9+ KB

# %%
# prepare the variables:dependent,independent and the constant
y_car = toyata['Price']

X_car = toyata[['Age', 'KM','HP', 'MetColor', 'Automatic']]

X_with_intercept_car = sm.add_constant(X_car)

# Fit the linear regression model ols means ordinatry list square
model_car = sm.OLS(y_car, X_with_intercept_car)
results_car = model_car.fit()

# %%
results_car.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.813
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     1240.
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):               0.00
# Time:                        14:47:02   Log-Likelihood:                -12605.
# No. Observations:                1436   AIC:                         2.522e+04
# Df Residuals:                    1430   BIC:                         2.525e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.637e+04    355.781     45.998      0.000    1.57e+04    1.71e+04
# ...

# %% [markdown]
# for that two dummy variable:
#     metcolor:comparing to cars with no metallic ,cars with it sellls 44 dollars more,holding everything else constant
#         automatic:comparing to cars with no auto transmission,cars with it sells for 748 dollars more,holding everything else constant

# %%
toyata['Fuel_Type'].unique()
toyata['Fuel_Type']=toyata['Fuel_Type'].astype('category')
# Out:
# array(['Diesel', 'Petrol', 'CNG'], dtype=object)

# %%
#change the variable data from integer to category
toyata['Doors'].unique()
toyata['Doors']=toyata['Doors'].astype('category')
# Out:
# array([3, 5, 4, 2])

# %%
y_car = toyata['Price']
X_car_1 = toyata[['Age', 'KM','HP', 'MetColor', 'Automatic','Fuel_Type','Doors']]

X_car_1 = pd.get_dummies(X_car_1,columns=['Fuel_Type','Doors'],drop_first=True,dtype=int)

# %%
X_car_1.head()
# Out:
#    Age     KM  HP  MetColor  Automatic  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0   23  46986  90         1          0                 1                 0
# 1   23  72937  90         1          0                 1                 0
# 2   24  41711  90         1          0                 1                 0
# 3   26  48000  90         0          0                 1                 0
# 4   30  38500  90         0          0                 1                 0
#
#    Doors_3  Doors_4  Doors_5
# 0        1        0        0
# 1        1        0        0
# 2        1        0        0
# 3        1        0        0
# 4        1        0        0

# %%
# Example using reindex():
#y_reindexed = y.reindex(X_car_1.index)
y_car = toyata['Price']

# Add a constant term to the independent variables
X_with_intercept_car_1 = sm.add_constant(X_car_1)

# Fit the linear regression model
model_car_1 = sm.OLS(y_car, X_with_intercept_car_1)
results_car_1 = model_car_1.fit()

# Display the summary of regression results
print(results_car_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.835
# Method:                 Least Squares   F-statistic:                     729.4
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):               0.00
# Time:                        14:47:02   Log-Likelihood:                -12506.
# No. Observations:                1436   AIC:                         2.503e+04
# Df Residuals:                    1425   BIC:                         2.509e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             1.342e+04   1170.837     11.461      0.000    1.11e+04    1.57e+04
# ...

# %% [markdown]
# 4. make predictions
